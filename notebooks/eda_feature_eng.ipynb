# %%
import sys

sys.path.append("../src")

import altair as alt

alt.renderers.enable("jupyter", offline=True)
alt.data_transformers.disable_max_rows()

from pathlib import Path

import altair as alt
import numpy as np
import polars as pl
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

from config import cfg
from data.data_process import add_fold
from data.simple_feature_eng import preprocess

# warnings.filterwarnings("ignore")
# warnings.simplefilter("ignore")


def plot_point(df: pl.DataFrame):
    transforms = [pl.col(col).cast(pl.Float64) for col in ["Episode_Length_minutes", "Listening_Time_minutes"]]
    df = df.with_columns(transforms)

    print("Length:", len(df))
    df.plot.point(
        x="Episode_Length_minutes",
        y="Listening_Time_minutes",
    ).properties(
        width=800,
        height=400,
    ).show()


def plot_linear_regression(df):
    X = df.select("Episode_Length_minutes").to_numpy()
    y = df.select("Listening_Time_minutes").to_numpy()

    model = LinearRegression()
    model.fit(X, y)
    predictions = model.predict(X)

    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y, predictions))

    print(f"Coefficient: {model.coef_[0][0]:.4f}")
    print(f"Intercept: {model.intercept_[0]:.4f}")
    print(f"RMSE: {rmse:.4f}")

    df = df.with_columns(pl.Series("Predicted", predictions.flatten()))
    if len(df) > 10000:
        df = df.sample(10000)

    scatter_plot = (
        alt.Chart(df.to_pandas())
        .mark_circle()
        .encode(
            x=alt.X("Episode_Length_minutes", title="Episode Length (minutes)"),
            y=alt.Y("Listening_Time_minutes", title="Listening Time (minutes)"),
            tooltip=["Episode_Length_minutes", "Listening_Time_minutes"],
        )
    )

    regression_line = alt.Chart(df.to_pandas()).mark_line(color="red").encode(x="Episode_Length_minutes", y="Predicted")

    chart = (scatter_plot + regression_line).properties(
        width=800,
        height=400,
    )

    return chart.show()


cfg.train_path = Path("../data/train.csv")
cfg.test_path = Path("../data/test.csv")
cfg.pltpd_path = Path("../data/podcast_dataset.csv")


df_test = pl.read_csv(cfg.test_path)

df_train = pl.read_csv(cfg.train_path)
df_train = df_train.drop_nulls(subset=["Episode_Length_minutes", "Number_of_Ads"])


# df_train = df_train.drop("id")
df_train = add_fold(df_train)
df_train = preprocess(df_train)

df_pltpd = pl.read_csv(cfg.pltpd_path)
df_pltpd = df_pltpd.drop_nulls(subset=["Episode_Length_minutes", "Number_of_Ads", "Listening_Time_minutes"])
df_pltpd = df_pltpd.with_columns(pl.col("Number_of_Ads").cast(pl.Float64))
df_pltpd = add_fold(df_pltpd)
df_pltpd = preprocess(df_pltpd)
df_pltpd = df_pltpd.with_columns(pl.Series(range(1_000_000, 1_000_000 + len(df_pltpd))).alias("id"))
# df_pltpd

df_train = df_train.drop(["id", "fold"])
df_pltpd = df_pltpd.drop(["id", "fold"])

df = df_train.clone()
df
# Out:
# shape: (662_906, 14)
# ┌────────────┬────────────┬───────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Podcast_Na ┆ Episode_Le ┆ Genre ┆ Host_Popul ┆ … ┆ Episode_N ┆ Episode_L ┆ Guest_Pop ┆ Episode_N │
# │ me         ┆ ngth_minut ┆ ---   ┆ arity_perc ┆   ┆ um        ┆ ength_min ┆ ularity_p ┆ um_Cat    │
# │ ---        ┆ es         ┆ str   ┆ entage     ┆   ┆ ---       ┆ utes_NaN  ┆ ercentage ┆ ---       │
# │ str        ┆ ---        ┆       ┆ ---        ┆   ┆ i32       ┆ ---       ┆ _Na…      ┆ cat       │
# │            ┆ f64        ┆       ┆ f64        ┆   ┆           ┆ cat       ┆ ---       ┆           │
# │            ┆            ┆       ┆            ┆   ┆           ┆           ┆ cat       ┆           │
# ╞════════════╪════════════╪═══════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1          ┆ 119.8      ┆ 1     ┆ 66.95      ┆ … ┆ 26        ┆ false     ┆ false     ┆ 26        │
# │ 2          ┆ 73.9       ┆ 2     ┆ 69.97      ┆ … ┆ 16        ┆ false     ┆ false     ┆ 16        │
# │ 3          ┆ 67.17      ┆ 3     ┆ 57.22      ┆ … ┆ 45        ┆ false     ┆ false     ┆ 45        │
# │ 4          ┆ 110.51     ┆ 4     ┆ 80.07      ┆ … ┆ 86        ┆ false     ┆ false     ┆ 86        │
# │ 5          ┆ 26.54      ┆ 4     ┆ 48.96      ┆ … ┆ 19        ┆ false     ┆ true      ┆ 19        │
# │ …          ┆ …          ┆ …     ┆ …          ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 36         ┆ 75.66      ┆ 2     ┆ 69.36      ┆ … ┆ 25        ┆ false     ┆ true      ┆ 25        │
# │ 19         ┆ 75.75      ┆ 8     ┆ 35.21      ┆ … ┆ 21        ┆ false     ┆ true      ┆ 21        │
# │ 37         ┆ 30.98      ┆ 9     ┆ 78.58      ┆ … ┆ 51        ┆ false     ┆ false     ┆ 51        │
# │ 28         ┆ 108.98     ┆ 9     ┆ 45.39      ┆ … ┆ 47        ┆ false     ┆ false     ┆ 47        │
# │ 10         ┆ 24.1       ┆ 7     ┆ 22.45      ┆ … ┆ 99        ┆ false     ┆ false     ┆ 99        │
# └────────────┴────────────┴───────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
pl_i_type = pl.Int32
pl_f_type = pl.Float32

def feature_eng(df: pl.DataFrame, df_train: pl.DataFrame) -> pl.DataFrame:
    global selected
    # Cyclical features for day and time
    df = df.with_columns(
        # Day features
        pl.col("Publication_Day").cast(pl_f_type).mul(2 * np.pi / 7).sin().alias("Day_sin"),
        pl.col("Publication_Day").cast(pl_f_type).mul(2 * np.pi / 7).cos().alias("Day_cos"),
        pl.col("Publication_Day").cast(pl_f_type).mul(4 * np.pi / 7).sin().alias("Day_sin2"),
        pl.col("Publication_Day").cast(pl_f_type).mul(4 * np.pi / 7).cos().alias("Day_cos2"),
        # Time features
        pl.col("Publication_Time").cast(pl_f_type).mul(2 * np.pi / 4).sin().alias("Time_sin"),
        pl.col("Publication_Time").cast(pl_f_type).mul(2 * np.pi / 4).cos().alias("Time_cos"),
        pl.col("Publication_Time").cast(pl_f_type).mul(4 * np.pi / 24).sin().alias("Time_sin2"),
        pl.col("Publication_Time").cast(pl_f_type).mul(4 * np.pi / 24).cos().alias("Time_cos2"),
        # Ratio features
        (pl.col("Episode_Length_minutes") / (pl.col("Number_of_Ads") + 1)).fill_null(0).alias("Length_per_Ads"),
        (pl.col("Episode_Length_minutes") / (pl.col("Host_Popularity_percentage") + 1)).fill_null(0).alias("Length_per_Host"),
        (pl.col("Episode_Length_minutes") / (pl.col("Guest_Popularity_percentage") + 1)).fill_null(0).alias("Length_per_Guest"),
        # Episode length features
        pl.col("Episode_Length_minutes").floor().alias("ELen_Int"),
        (pl.col("Episode_Length_minutes") - pl.col("Episode_Length_minutes").floor()).alias("ELen_Dec"),
        pl.col("Host_Popularity_percentage").floor().alias("HPperc_Int"),
        (pl.col("Host_Popularity_percentage") - pl.col("Host_Popularity_percentage").floor()).alias("HPperc_Dec"),
        # Sentiment features
        (pl.col("Episode_Sentiment") == "2").cast(pl.Int8).alias("Is_Positive_Sentiment"),
        pl.when(pl.col("Episode_Sentiment") == "2").then(0.75).otherwise(0.717).cast(pl_f_type).alias("Sentiment_Multiplier"),
        # Squared features
        (pl.col("Episode_Length_minutes") ** 2).alias("Episode_Length_squared"),
        (pl.col("Episode_Length_minutes") ** 3).alias("Episode_Length_squared2"),
    )

    df = df.with_columns(
        (np.sin(2 * np.pi * pl.col("Episode_Num") / 100)).alias("Long_Term_Cycle_Sin"),
        (np.cos(2 * np.pi * pl.col("Episode_Num") / 100)).alias("Long_Term_Cycle_Cos"),
        (pl.col("Episode_Length_minutes") * pl.col("Sentiment_Multiplier")).alias("Expected_Listening_Time_Sentiment"),
    )

    # Convert columns to categorical
    df = df.with_columns(pl.col("Episode_Num").cast(pl_i_type).alias("Episode_Num_Int"))
    for col in ["Podcast_Name", "Genre", "Publication_Day", "Publication_Time", "Episode_Sentiment", "Episode_Num"]:
        df = df.with_columns(pl.col(col).cast(pl.Utf8).cast(pl.Categorical))

    return df

df_train = df.clone()
df_train = feature_eng(df_train, df_train)
df_train
# Out:
# shape: (662_906, 37)
# ┌────────────┬────────────┬───────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Podcast_Na ┆ Episode_Le ┆ Genre ┆ Host_Popul ┆ … ┆ Long_Term ┆ Long_Term ┆ Expected_ ┆ Episode_N │
# │ me         ┆ ngth_minut ┆ ---   ┆ arity_perc ┆   ┆ _Cycle_Si ┆ _Cycle_Co ┆ Listening ┆ um_Int    │
# │ ---        ┆ es         ┆ cat   ┆ entage     ┆   ┆ n         ┆ s         ┆ _Time_Sen ┆ ---       │
# │ cat        ┆ ---        ┆       ┆ ---        ┆   ┆ ---       ┆ ---       ┆ tim…      ┆ i32       │
# │            ┆ f64        ┆       ┆ f64        ┆   ┆ f64       ┆ f64       ┆ ---       ┆           │
# │            ┆            ┆       ┆            ┆   ┆           ┆           ┆ f64       ┆           │
# ╞════════════╪════════════╪═══════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1          ┆ 119.8      ┆ 1     ┆ 66.95      ┆ … ┆ 0.998027  ┆ -0.062791 ┆ 85.896601 ┆ 26        │
# │ 2          ┆ 73.9       ┆ 2     ┆ 69.97      ┆ … ┆ 0.844328  ┆ 0.535827  ┆ 52.986301 ┆ 16        │
# │ 3          ┆ 67.17      ┆ 3     ┆ 57.22      ┆ … ┆ 0.309017  ┆ -0.951057 ┆ 50.3775   ┆ 45        │
# │ 4          ┆ 110.51     ┆ 4     ┆ 80.07      ┆ … ┆ -0.770513 ┆ 0.637424  ┆ 79.235671 ┆ 86        │
# │ 5          ┆ 26.54      ┆ 4     ┆ 48.96      ┆ … ┆ 0.929776  ┆ 0.368125  ┆ 19.905    ┆ 19        │
# │ …          ┆ …          ┆ …     ┆ …          ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 36         ┆ 75.66      ┆ 2     ┆ 69.36      ┆ … ┆ 1.0       ┆ 6.1232e-1 ┆ 54.248221 ┆ 25        │
# │            ┆            ┆       ┆            ┆   ┆           ┆ 7         ┆           ┆           │
# │ 19         ┆ 75.75      ┆ 8     ┆ 35.21      ┆ … ┆ 0.968583  ┆ 0.24869   ┆ 54.312751 ┆ 21        │
# │ 37         ┆ 30.98      ┆ 9     ┆ 78.58      ┆ … ┆ -0.062791 ┆ -0.998027 ┆ 22.21266  ┆ 51        │
# │ 28         ┆ 108.98     ┆ 9     ┆ 45.39      ┆ … ┆ 0.187381  ┆ -0.982287 ┆ 78.138661 ┆ 47        │
# │ 10         ┆ 24.1       ┆ 7     ┆ 22.45      ┆ … ┆ -0.062791 ┆ 0.998027  ┆ 17.2797   ┆ 99        │
# └────────────┴────────────┴───────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
alt.Chart(df_train.sample(10000)).mark_bar().encode(
    x=alt.X('Listening_Time_minutes', bin=True),
    y=alt.Y('count()')
)
# Out:
# JupyterChart(spec={'config': {'view': {'continuousWidth': 300, 'continuousHeight': 300}}, 'data': {'name': 'da…

# %%
df_train.filter(pl.col("Episode_Length_minutes_round_3_dec") != 0)
# Out:
# shape: (32_671, 52)
# ┌────────────┬────────────┬───────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Podcast_Na ┆ Episode_Le ┆ Genre ┆ Host_Popul ┆ … ┆ Host_Popu ┆ Long_Term ┆ Long_Term ┆ Expected_ │
# │ me         ┆ ngth_minut ┆ ---   ┆ arity_perc ┆   ┆ larity_pe ┆ _Cycle_Si ┆ _Cycle_Co ┆ Listening │
# │ ---        ┆ es         ┆ cat   ┆ entage     ┆   ┆ rcentage_ ┆ n         ┆ s         ┆ _Time_Sen │
# │ cat        ┆ ---        ┆       ┆ ---        ┆   ┆ rou…      ┆ ---       ┆ ---       ┆ tim…      │
# │            ┆ f64        ┆       ┆ f64        ┆   ┆ ---       ┆ f64       ┆ f64       ┆ ---       │
# │            ┆            ┆       ┆            ┆   ┆ f64       ┆           ┆           ┆ f64       │
# ╞════════════╪════════════╪═══════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 27         ┆ 33.23      ┆ 4     ┆ 43.35      ┆ … ┆ 0.0       ┆ 1.0       ┆ 6.1232e-1 ┆ 23.82591  │
# │            ┆            ┆       ┆            ┆   ┆           ┆           ┆ 7         ┆           │
# │ 26         ┆ 19.56      ┆ 7     ┆ 93.77      ┆ … ┆ 0.0       ┆ -0.968583 ┆ 0.24869   ┆ 14.67     │
# │ 37         ┆ 72.32      ┆ 9     ┆ 78.69      ┆ … ┆ 0.0       ┆ 0.770513  ┆ -0.637424 ┆ 51.853441 │
# │ 42         ┆ 77.6       ┆ 8     ┆ 79.63      ┆ … ┆ 0.0       ┆ 0.992115  ┆ 0.125333  ┆ 55.639201 │
# │ 9          ┆ 64.57      ┆ 6     ┆ 84.75      ┆ … ┆ 0.0       ┆ -0.535827 ┆ -0.844328 ┆ 46.29669  │
# │ …          ┆ …          ┆ …     ┆ …          ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 6          ┆ 78.24      ┆ 0     ┆ 57.37      ┆ … ┆ 0.0       ┆ -0.368125 ┆ -0.929776 ┆ 56.098081 │
# │ 31         ┆ 67.32      ┆ 8     ┆ 98.59      ┆ … ┆ 0.0       ┆ -0.904827 ┆ -0.425779 ┆ 50.49     │
# │ 17         ┆ 32.62      ┆ 1     ┆ 73.07      ┆ … ┆ 10.0      ┆ -0.998027 ┆ -0.062791 ┆ 23.38854  │
# │ 11         ┆ 16.4       ┆ 6     ┆ 61.49      ┆ … ┆ 0.0       ┆ 0.770513  ┆ -0.637424 ┆ 11.7588   │
# │ 9          ┆ 18.08      ┆ 6     ┆ 43.21      ┆ … ┆ 0.0       ┆ 0.876307  ┆ -0.481754 ┆ 12.96336  │
# └────────────┴────────────┴───────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
import polars as pl
import numpy as np
from sklearn.manifold import TSNE
import altair as alt

df_train = df_train.with_columns(
    pl.col("Genre").cast(pl.Int32),
    pl.col("Publication_Day").cast(pl.Int32),
    pl.col("Publication_Time").cast(pl.Int32),
    pl.col("Episode_Sentiment").cast(pl.Int32),
)
df_train = df_train.sample(1000)

features = df_train.select([
    "Episode_Length_minutes",
    "Listening_Time_minutes",
    "Genre",
    "Host_Popularity_percentage",
    "Guest_Popularity_percentage",
    "Publication_Day",
    "Publication_Time",
    "Number_of_Ads",
    "Episode_Sentiment",
    "Episode_Num",
]).to_numpy()

tsne = TSNE(n_components=2, random_state=42, perplexity=30)
tsne_results = tsne.fit_transform(features)

df = df.with_columns([
    pl.Series("tsne_1", tsne_results[:, 0]),
    pl.Series("tsne_2", tsne_results[:, 1])
])

chart = alt.Chart(df).mark_circle(size=60).encode(
    x='tsne_1:Q',
    y='tsne_2:Q',
    color=alt.Color('label:N', scale=alt.Scale(scheme='Listening_Time_minutes')),
    tooltip=['label:N']
).properties(
    width=600,
    height=400,
    title='t-SNE Visualization of High-Dimensional Data'
).interactive()

chart.show()

# %%
# Out:
# [['Guest_Popularity_percentage_NaN', 'ELen_Int'],
#  ['Episode_Sentiment', 'ELen_Int'],
#  ['Number_of_Ads', 'ELen_Int'],
#  ['Number_of_Ads', 'Episode_Length_minutes_NaN', 'ELen_Int'],
#  ['ELen_Dec'],
#  ['Episode_Sentiment', 'Guest_Popularity_percentage_NaN', 'ELen_Int'],
#  ['Number_of_Ads', 'Guest_Popularity_percentage_NaN', 'ELen_Int'],
#  ['Publication_Time', 'Guest_Popularity_percentage_NaN', 'ELen_Int'],
#  ['Number_of_Ads', 'Episode_Sentiment', 'ELen_Int'],
#  ['Publication_Time', 'Number_of_Ads', 'ELen_Int'],
#  ['Genre', 'Guest_Popularity_percentage_NaN', 'ELen_Int'],
#  ['Publication_Day', 'Number_of_Ads', 'ELen_Int'],
#  ['Genre', 'Number_of_Ads', 'ELen_Int'],
#  ['Podcast_Name', 'ELen_Int'],
#  ['Podcast_Name', 'Genre', 'ELen_Int'],
#  ['ELen_Int', 'HPperc_Int'],
#  ['ELen_Int', 'ELen_Dec'],
#  ['Episode_Length_minutes_NaN', 'ELen_Int', 'ELen_Dec'],
#  ['Episode_Num', 'Episode_Length_minutes_NaN', 'ELen_Int'],
#  ['Host_Popularity_percentage', 'Episode_Num', 'Length_per_Guest'],
#  ['Podcast_Name', 'Host_Popularity_percentage', 'Length_per_Guest'],
#  ['Host_Popularity_percentage', 'Episode_Num', 'Length_per_Ads'],
#  ['Podcast_Name', 'Host_Popularity_percentage', 'Length_per_Ads'],
#  ['Host_Popularity_percentage', 'Length_per_Ads', 'Length_per_Guest'],
#  ['Episode_Length_minutes', 'Host_Popularity_percentage', 'Length_per_Guest'],
#  ['Length_per_Host', 'Length_per_Guest', 'ELen_Int'],
#  ['Length_per_Host', 'Length_per_Guest'],
#  ['Episode_Length_minutes',
#   'Episode_Length_minutes_NaN',
#   'Guest_Popularity_percentage_NaN'],
#  ['Episode_Length_minutes', 'Host_Popularity_percentage', 'Episode_Num'],
#  ['Guest_Popularity_percentage', 'Length_per_Ads', 'Length_per_Host'],
#  ['Episode_Num', 'Guest_Popularity_percentage_NaN', 'ELen_Int'],
#  ['Number_of_Ads', 'Length_per_Ads', 'ELen_Int'],
#  ['Host_Popularity_percentage',
#   'Guest_Popularity_percentage',
#   'Length_per_Guest'],
#  ['Episode_Length_minutes', 'Guest_Popularity_percentage', 'HPperc_Dec'],
#  ['Length_per_Guest', 'HPperc_Dec'],
#  ['Host_Popularity_percentage',
#   'Guest_Popularity_percentage',
#   'Length_per_Host'],
#  ['Guest_Popularity_percentage', 'Episode_Num', 'Length_per_Ads'],
#  ['Podcast_Name', 'Guest_Popularity_percentage', 'Episode_Num'],
#  ['Episode_Length_minutes', 'Guest_Popularity_percentage', 'Length_per_Host'],
#  ['Podcast_Name', 'Guest_Popularity_percentage', 'HPperc_Int'],
#  ['Host_Popularity_percentage', 'Episode_Num', 'ELen_Dec'],
#  ['Episode_Length_minutes', 'Guest_Popularity_percentage', 'Episode_Num'],
#  ['Guest_Popularity_percentage', 'Length_per_Ads', 'HPperc_Int'],
#  ['Host_Popularity_percentage', 'Episode_Num', 'Length_per_Host'],
#  ['Genre', 'Host_Popularity_percentage', 'Length_per_Guest'],
#  ['Host_Popularity_percentage', 'Length_per_Host', 'Length_per_Guest'],
#  ['Host_Popularity_percentage', 'Guest_Popularity_percentage', 'ELen_Int'],
#  ['Podcast_Name', 'Episode_Length_minutes', 'Episode_Num'],
#  ['Episode_Length_minutes', 'Guest_Popularity_percentage', 'HPperc_Int'],
#  ['Length_per_Guest', 'HPperc_Int'],
#  ['Episode_Sentiment', 'ELen_Int', 'ELen_Dec'],
#  ['Host_Popularity_percentage', 'Length_per_Guest', 'ELen_Int'],
#  ['Podcast_Name', 'Episode_Length_minutes', 'HPperc_Int'],
#  ['Podcast_Name', 'Guest_Popularity_percentage', 'ELen_Int'],
#  ['Host_Popularity_percentage', 'Episode_Num', 'ELen_Int'],
#  ['Episode_Sentiment', 'Episode_Num', 'ELen_Int'],
#  ['Podcast_Name', 'Episode_Length_minutes', 'Length_per_Host'],
#  ['Episode_Length_minutes', 'Episode_Num', 'HPperc_Int'],
#  ['Podcast_Name', 'Episode_Length_minutes', 'Guest_Popularity_percentage'],
#  ['Host_Popularity_percentage', 'Length_per_Host', 'ELen_Dec'],
#  ['Length_per_Host', 'ELen_Int', 'HPperc_Int'],
#  ['Length_per_Host', 'ELen_Int'],
#  ['Guest_Popularity_percentage', 'Length_per_Host', 'HPperc_Int'],
#  ['Guest_Popularity_percentage', 'Episode_Num', 'ELen_Int'],
#  ['Number_of_Ads', 'ELen_Int', 'HPperc_Int'],
#  ['Episode_Length_minutes', 'Length_per_Host', 'HPperc_Dec'],
#  ['Guest_Popularity_percentage', 'ELen_Int', 'HPperc_Int'],
#  ['Episode_Length_minutes',
#   'Host_Popularity_percentage',
#   'Guest_Popularity_percentage_NaN'],
#  ['Guest_Popularity_percentage', 'Length_per_Host', 'ELen_Int'],
#  ['Episode_Length_minutes', 'Host_Popularity_percentage', 'Episode_Sentiment'],
#  ['Publication_Time', 'Guest_Popularity_percentage', 'Length_per_Host'],
#  ['Guest_Popularity_percentage', 'Length_per_Guest', 'HPperc_Int'],
#  ['Podcast_Name', 'Host_Popularity_percentage', 'ELen_Int'],
#  ['Episode_Length_minutes', 'Guest_Popularity_percentage', 'ELen_Int'],
#  ['Length_per_Guest', 'ELen_Int'],
#  ['Guest_Popularity_percentage', 'Length_per_Host', 'Length_per_Guest'],
#  ['Host_Popularity_percentage', 'Length_per_Ads', 'ELen_Dec'],
#  ['Length_per_Ads', 'Length_per_Host', 'HPperc_Dec'],
#  ['Guest_Popularity_percentage', 'Episode_Num', 'Length_per_Guest'],
#  ['Episode_Length_minutes', 'Episode_Num', 'Length_per_Guest'],
#  ['Episode_Length_minutes', 'Length_per_Host', 'Length_per_Guest'],
#  ['Podcast_Name', 'Length_per_Ads', 'HPperc_Int'],
#  ['Host_Popularity_percentage', 'Length_per_Ads', 'ELen_Int'],
#  ['Number_of_Ads', 'ELen_Int', 'ELen_Dec'],
#  ['Length_per_Ads', 'ELen_Dec'],
#  ['Episode_Length_minutes', 'Length_per_Ads'],
#  ['Length_per_Host'],
#  ['Episode_Length_minutes', 'Publication_Time', 'Episode_Length_minutes_NaN'],
#  ['Length_per_Guest'],
#  ['Episode_Length_minutes_NaN', 'Length_per_Guest', 'ELen_Int'],
#  ['Episode_Length_minutes', 'Length_per_Guest', 'HPperc_Int'],
#  ['Host_Popularity_percentage',
#   'Episode_Length_minutes_NaN',
#   'Length_per_Ads'],
#  ['Guest_Popularity_percentage', 'Episode_Sentiment', 'Length_per_Host'],
#  ['Number_of_Ads', 'Episode_Num', 'ELen_Int'],
#  ['Episode_Length_minutes', 'Genre', 'HPperc_Dec'],
#  ['Podcast_Name', 'Episode_Length_minutes', 'Length_per_Guest'],
#  ['Genre', 'Length_per_Ads', 'HPperc_Dec'],
#  ['Genre', 'Length_per_Ads', 'Length_per_Host'],
#  ['Episode_Length_minutes', 'Genre', 'Length_per_Host'],
#  ['Episode_Length_minutes', 'Genre', 'Episode_Num'],
#  ['Guest_Popularity_percentage', 'Length_per_Ads', 'Length_per_Guest'],
#  ['Publication_Day', 'Guest_Popularity_percentage', 'Length_per_Ads'],
#  ['Genre', 'Guest_Popularity_percentage', 'ELen_Int'],
#  ['Episode_Length_minutes',
#   'Episode_Sentiment',
#   'Guest_Popularity_percentage_NaN'],
#  ['Genre', 'Episode_Num', 'Length_per_Ads'],
#  ['Episode_Length_minutes', 'Genre', 'HPperc_Int'],
#  ['Episode_Length_minutes', 'Publication_Day', 'HPperc_Dec'],
#  ['Publication_Time', 'Guest_Popularity_percentage', 'Length_per_Guest'],
#  ['Publication_Day', 'Length_per_Ads', 'Length_per_Host'],
#  ['Episode_Length_minutes', 'Publication_Day', 'Length_per_Host'],
#  ['Number_of_Ads', 'Episode_Sentiment', 'Length_per_Ads'],
#  ['Genre', 'Length_per_Ads', 'HPperc_Int'],
#  ['Publication_Day', 'Guest_Popularity_percentage', 'ELen_Int'],
#  ['Episode_Length_minutes', 'Publication_Day', 'Episode_Num'],
#  ['Length_per_Ads', 'Length_per_Host', 'HPperc_Int'],
#  ['Genre', 'Length_per_Ads', 'Length_per_Guest'],
#  ['Episode_Length_minutes', 'Genre', 'Length_per_Guest'],
#  ['Publication_Day', 'Episode_Num', 'Length_per_Ads'],
#  ['Episode_Length_minutes',
#   'Publication_Time',
#   'Guest_Popularity_percentage_NaN'],
#  ['Publication_Day', 'ELen_Int', 'ELen_Dec'],
#  ['Episode_Length_minutes', 'Publication_Day'],
#  ['Episode_Length_minutes', 'Publication_Day', 'HPperc_Int'],
#  ['Episode_Length_minutes', 'Publication_Day', 'Length_per_Guest'],
#  ['Publication_Time', 'Length_per_Ads', 'Length_per_Host'],
#  ['Publication_Time', 'Guest_Popularity_percentage', 'ELen_Int'],
#  ['Publication_Day', 'Length_per_Ads', 'HPperc_Int'],
#  ['Publication_Time', 'Length_per_Guest', 'ELen_Int'],
#  ['Guest_Popularity_percentage', 'Number_of_Ads', 'ELen_Int'],
#  ['Episode_Length_minutes', 'Publication_Time', 'Length_per_Guest'],
#  ['Episode_Length_minutes', 'Length_per_Ads', 'Length_per_Guest'],
#  ['Episode_Length_minutes', 'Publication_Time', 'Length_per_Host'],
#  ['Episode_Length_minutes', 'Length_per_Ads', 'Length_per_Host'],
#  ['Episode_Length_minutes', 'Episode_Sentiment', 'Length_per_Guest'],
#  ['Episode_Length_minutes', 'Publication_Time', 'HPperc_Dec'],
#  ['Episode_Length_minutes', 'Number_of_Ads', 'HPperc_Dec'],
#  ['Length_per_Ads', 'ELen_Dec', 'HPperc_Dec'],
#  ['Episode_Length_minutes', 'Publication_Time', 'Episode_Num'],
#  ['Number_of_Ads', 'Length_per_Ads', 'Length_per_Guest'],
#  ['Episode_Length_minutes', 'Episode_Num', 'Length_per_Ads'],
#  ['Episode_Num', 'Length_per_Ads', 'ELen_Dec'],
#  ['Host_Popularity_percentage', 'Number_of_Ads', 'Length_per_Host'],
#  ['Episode_Length_minutes', 'Episode_Sentiment', 'Length_per_Host'],
#  ['Podcast_Name', 'Episode_Length_minutes', 'Publication_Day'],
#  ['Guest_Popularity_percentage', 'Length_per_Guest'],
#  ['Guest_Popularity_percentage',
#   'Episode_Length_minutes_NaN',
#   'Length_per_Guest'],
#  ['Episode_Length_minutes', 'Genre'],
#  ['Episode_Length_minutes', 'Length_per_Guest', 'ELen_Int'],
#  ['Episode_Length_minutes', 'Episode_Length_minutes_NaN', 'Length_per_Guest'],
#  ['Episode_Length_minutes',
#   'Guest_Popularity_percentage_NaN',
#   'Length_per_Guest'],
#  ['Episode_Length_minutes', 'Length_per_Ads', 'HPperc_Int'],
#  ['Length_per_Ads', 'ELen_Dec', 'HPperc_Int'],
#  ['Episode_Length_minutes', 'Episode_Sentiment', 'Episode_Num'],
#  ['Guest_Popularity_percentage_NaN', 'Length_per_Ads', 'Length_per_Guest'],
#  ['Episode_Sentiment', 'Length_per_Ads', 'ELen_Dec'],
#  ['Length_per_Ads', 'HPperc_Dec'],
#  ['Episode_Length_minutes', 'Episode_Sentiment', 'Length_per_Ads'],
#  ['Number_of_Ads', 'Length_per_Ads', 'Length_per_Host'],
#  ['Episode_Sentiment', 'Episode_Num', 'Length_per_Ads'],
#  ['Guest_Popularity_percentage_NaN', 'Length_per_Ads', 'Length_per_Host'],
#  ['Episode_Length_minutes', 'Episode_Sentiment', 'HPperc_Int'],
#  ['Episode_Num', 'Length_per_Guest', 'ELen_Int'],
#  ['Episode_Length_minutes',
#   'Guest_Popularity_percentage_NaN',
#   'Length_per_Host'],
#  ['Podcast_Name', 'Length_per_Guest', 'ELen_Int'],
#  ['Episode_Length_minutes', 'Length_per_Host', 'HPperc_Int'],
#  ['Number_of_Ads', 'Length_per_Ads', 'HPperc_Dec'],
#  ['Episode_Num', 'Length_per_Ads', 'ELen_Int'],
#  ['Number_of_Ads', 'Episode_Num', 'Length_per_Ads'],
#  ['Host_Popularity_percentage',
#   'Guest_Popularity_percentage_NaN',
#   'Length_per_Host'],
#  ['Podcast_Name', 'Episode_Length_minutes', 'Length_per_Ads'],
#  ['Podcast_Name', 'Episode_Length_minutes', 'Number_of_Ads'],
#  ['Podcast_Name', 'Length_per_Ads', 'ELen_Dec'],
#  ['Guest_Popularity_percentage',
#   'Guest_Popularity_percentage_NaN',
#   'ELen_Int'],
#  ['Guest_Popularity_percentage', 'Episode_Length_minutes_NaN', 'ELen_Int'],
#  ['Host_Popularity_percentage', 'Length_per_Host', 'ELen_Int'],
#  ['Episode_Length_minutes', 'Episode_Length_minutes_NaN', 'Length_per_Host'],
#  ['Episode_Length_minutes', 'Episode_Num', 'Guest_Popularity_percentage_NaN'],
#  ['Number_of_Ads', 'Length_per_Ads', 'HPperc_Int'],
#  ['Podcast_Name', 'Episode_Length_minutes', 'Episode_Sentiment'],
#  ['Episode_Length_minutes', 'Guest_Popularity_percentage_NaN', 'HPperc_Int'],
#  ['Host_Popularity_percentage', 'Length_per_Host', 'HPperc_Int'],
#  ['Host_Popularity_percentage',
#   'Episode_Length_minutes_NaN',
#   'Length_per_Host'],
#  ['Genre', 'Length_per_Ads', 'ELen_Int'],
#  ['Episode_Length_minutes', 'Publication_Day', 'Episode_Sentiment'],
#  ['Host_Popularity_percentage', 'Guest_Popularity_percentage_NaN', 'ELen_Int'],
#  ['Episode_Length_minutes', 'Episode_Num'],
#  ['Episode_Length_minutes', 'Episode_Num', 'Episode_Length_minutes_NaN'],
#  ['Episode_Length_minutes', 'Episode_Length_minutes_NaN', 'HPperc_Dec'],
#  ['Podcast_Name', 'Episode_Length_minutes', 'Guest_Popularity_percentage_NaN'],
#  ['Podcast_Name', 'Length_per_Ads', 'ELen_Int'],
#  ['Podcast_Name', 'Number_of_Ads', 'Length_per_Ads'],
#  ['Episode_Length_minutes', 'HPperc_Int'],
#  ['Episode_Num', 'Length_per_Ads'],
#  ['Episode_Num', 'ELen_Int', 'HPperc_Int'],
#  ['Genre', 'Length_per_Ads', 'ELen_Dec'],
#  ['Episode_Length_minutes', 'Genre', 'Publication_Day'],
#  ['Host_Popularity_percentage', 'ELen_Int', 'HPperc_Dec'],
#  ['Host_Popularity_percentage', 'Episode_Length_minutes_NaN', 'ELen_Int'],
#  ['Podcast_Name', 'Episode_Length_minutes', 'ELen_Int'],
#  ['Podcast_Name', 'Episode_Length_minutes', 'Episode_Length_minutes_NaN'],
#  ['Podcast_Name', 'ELen_Int', 'HPperc_Int']]

# %%
np.array([len(selected.split("-")) for selected in selecteds])
# Out:
# array([2, 2, 2, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 2, 2, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 1, 3,
#        1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3,
#        2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 3, 3,
#        3, 3])

# %%
df_train = pl.read_csv(cfg.train_path, infer_schema_length=0).with_columns(pl.all().cast(pl.String, strict=False))
df_pltpd = pl.read_csv(cfg.pltpd_path, infer_schema_length=0).with_columns(pl.all().cast(pl.String, strict=False))
df_test = pl.read_csv(cfg.test_path, infer_schema_length=0).with_columns(pl.all().cast(pl.String, strict=False))

# df_train = df_train.drop_nulls(subset=["Episode_Length_minutes", "Number_of_Ads", "Guest_Popularity_percentage", "Listening_Time_minutes"])
# df_pltpd = df_pltpd.drop_nulls(subset=["Episode_Length_minutes", "Number_of_Ads", "Guest_Popularity_percentage", "Listening_Time_minutes"])
# df_test = df_test.drop_nulls(subset=["Episode_Length_minutes", "Guest_Popularity_percentage"])

df_pltpd = df_pltpd.with_columns(pl.col("Number_of_Ads").cast(pl.Float64).cast(pl.String))

transforms = []
for col in ["Episode_Length_minutes", "Host_Popularity_percentage", "Guest_Popularity_percentage", "Number_of_Ads", "Listening_Time_minutes"]:
    transforms += [
        pl.when(pl.col(col).str.contains("\\."))
            .then(
                pl.col(col).str.extract(r"\.(\d+)$").str.len_chars().cast(pl.Int64)
            )
            .otherwise(pl.lit(0))
            .alias(f"{col}_Decimal_Len"),
        
        pl.when(pl.col(col).str.contains("\\."))
            .then(
                pl.col(col).str.extract(r"\.(\d+)$").cast(pl.Int64)
            )
            .otherwise(pl.lit(0))
            .alias(f"{col}_Decimal"),
        
        pl.col(col).cast(pl.Float64)
    ]

df_train = df_train.with_columns(transforms)
df_pltpd = df_pltpd.with_columns(transforms)
df_test = df_test.with_columns(transforms[:-3])

display(df_train)
# Out:
# shape: (750_000, 22)
# ┌────────┬────────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ id     ┆ Podcast_Na ┆ Episode_Ti ┆ Episode_L ┆ … ┆ Number_of ┆ Number_of ┆ Listening ┆ Listening │
# │ ---    ┆ me         ┆ tle        ┆ ength_min ┆   ┆ _Ads_Deci ┆ _Ads_Deci ┆ _Time_min ┆ _Time_min │
# │ str    ┆ ---        ┆ ---        ┆ utes      ┆   ┆ mal_Len   ┆ mal       ┆ utes_Deci ┆ utes_Deci │
# │        ┆ str        ┆ str        ┆ ---       ┆   ┆ ---       ┆ ---       ┆ mal…      ┆ mal       │
# │        ┆            ┆            ┆ f64       ┆   ┆ i64       ┆ i64       ┆ ---       ┆ ---       │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆ i64       ┆ i64       │
# ╞════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 0      ┆ Mystery    ┆ Episode 98 ┆ null      ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 41998     │
# │        ┆ Matters    ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1      ┆ Joke       ┆ Episode 26 ┆ 119.8     ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 1241      │
# │        ┆ Junction   ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2      ┆ Study      ┆ Episode 16 ┆ 73.9      ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 92531     │
# │        ┆ Sessions   ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 3      ┆ Digital    ┆ Episode 45 ┆ 67.17     ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 27824     │
# │        ┆ Digest     ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 4      ┆ Mind &     ┆ Episode 86 ┆ 110.51    ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 61031     │
# │        ┆ Body       ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …      ┆ …          ┆ …          ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 749995 ┆ Learning   ┆ Episode 25 ┆ 75.66     ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 87058     │
# │        ┆ Lab        ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 749996 ┆ Business   ┆ Episode 21 ┆ 75.75     ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 46242     │
# │        ┆ Briefs     ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 749997 ┆ Lifestyle  ┆ Episode 51 ┆ 30.98     ┆ … ┆ 1         ┆ 0         ┆ 2         ┆ 26        │
# │        ┆ Lounge     ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 749998 ┆ Style      ┆ Episode 47 ┆ 108.98    ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 72939     │
# │        ┆ Guide      ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 749999 ┆ Sports     ┆ Episode 99 ┆ 24.1      ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 94439     │
# │        ┆ Central    ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# └────────┴────────────┴────────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df = df_train.filter(pl.col("Episode_Length_minutes_Decimal_Len") > 2)
df
# Out:
# shape: (1_284, 22)
# ┌────────┬────────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ id     ┆ Podcast_Na ┆ Episode_Ti ┆ Episode_L ┆ … ┆ Number_of ┆ Number_of ┆ Listening ┆ Listening │
# │ ---    ┆ me         ┆ tle        ┆ ength_min ┆   ┆ _Ads_Deci ┆ _Ads_Deci ┆ _Time_min ┆ _Time_min │
# │ str    ┆ ---        ┆ ---        ┆ utes      ┆   ┆ mal_Len   ┆ mal       ┆ utes_Deci ┆ utes_Deci │
# │        ┆ str        ┆ str        ┆ ---       ┆   ┆ ---       ┆ ---       ┆ mal…      ┆ mal       │
# │        ┆            ┆            ┆ f64       ┆   ┆ i64       ┆ i64       ┆ ---       ┆ ---       │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆ i64       ┆ i64       │
# ╞════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 948    ┆ Educationa ┆ Episode 59 ┆ 96.10732  ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 10741     │
# │        ┆ l Nuggets  ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1745   ┆ Gadget     ┆ Episode 21 ┆ 54.468002 ┆ … ┆ 1         ┆ 0         ┆ 3         ┆ 468       │
# │        ┆ Geek       ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 3098   ┆ Market     ┆ Episode 62 ┆ 6.598     ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 59814     │
# │        ┆ Masters    ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 3448   ┆ Home &     ┆ Episode 48 ┆ 13.000003 ┆ … ┆ 1         ┆ 0         ┆ 1         ┆ 0         │
# │        ┆ Living     ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 3618   ┆ Health     ┆ Episode 67 ┆ 54.468002 ┆ … ┆ 1         ┆ 0         ┆ 3         ┆ 468       │
# │        ┆ Hour       ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …      ┆ …          ┆ …          ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 747943 ┆ Business   ┆ Episode 90 ┆ 29.378789 ┆ … ┆ 1         ┆ 0         ┆ 1         ┆ 0         │
# │        ┆ Insights   ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 748343 ┆ Tech       ┆ Episode 47 ┆ 112.002   ┆ … ┆ 1         ┆ 0         ┆ 1         ┆ 0         │
# │        ┆ Trends     ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 748407 ┆ Wellness   ┆ Episode 64 ┆ 6.712923  ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 71281     │
# │        ┆ Wave       ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 749034 ┆ Tune Time  ┆ Episode 89 ┆ 8.328313  ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 32831     │
# │ 749196 ┆ True Crime ┆ Episode 33 ┆ 62.167294 ┆ … ┆ 1         ┆ 0         ┆ 5         ┆ 16729     │
# │        ┆ Stories    ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# └────────┴────────────┴────────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
import numpy as np

def calculate_rmse(actual, predicted):
    squared_diff = (actual - predicted) ** 2
    mean_squared_diff = squared_diff.mean()
    rmse = np.sqrt(mean_squared_diff)
    return rmse

def optimize_scaling_factor(input_data, target_data, n_searches=20):
    initial_x = target_data.mean() / input_data.mean()
    
    # Define search range
    lower_bound = initial_x * 0.5
    upper_bound = initial_x * 1.5
    
    # Perform n binary searches
    for _ in range(n_searches):
        mid_point = (lower_bound + upper_bound) / 2
        
        delta = (upper_bound - lower_bound) * 0.1
        
        lower_x = mid_point - delta
        upper_x = mid_point + delta
        
        lower_rmse = calculate_rmse(target_data, input_data * lower_x)
        upper_rmse = calculate_rmse(target_data, input_data * upper_x)
        
        if lower_rmse < upper_rmse:
            upper_bound = mid_point
        else:
            lower_bound = mid_point
    
    best_x = (lower_bound + upper_bound) / 2
    best_rmse = calculate_rmse(target_data, input_data * best_x)
    
    return best_x, best_rmse

import time
for i in range(0, 100, 1):
    start_time = time.time()
    x_optimal = optimize_scaling_factor(df["Episode_Length_minutes"], df["Listening_Time_minutes"], n_searches=i)
    print(i, "\tCoefficient:", x_optimal[0], "\tRMSE:", x_optimal[1], "\tTime taken: ", time.time() - start_time)
# Out:
# 0 	Coefficient: 0.9598565775851021 	RMSE: 6.2916710331445485 	Time taken:  0.0009746551513671875
# 1 	Coefficient: 0.7198924331888266 	RMSE: 14.23471322374616 	Time taken:  0.0006189346313476562
# 2 	Coefficient: 0.8398745053869643 	RMSE: 8.918088931623851 	Time taken:  0.0019731521606445312
# 3 	Coefficient: 0.8998655414860333 	RMSE: 7.011795185255232 	Time taken:  0.00131988525390625
# 4 	Coefficient: 0.9298610595355676 	RMSE: 6.463500341295242 	Time taken:  0.0008881092071533203
# 5 	Coefficient: 0.9448588185603348 	RMSE: 6.327036445085333 	Time taken:  0.0013899803161621094
# 6 	Coefficient: 0.9523576980727184 	RMSE: 6.29649582675391 	Time taken:  0.0013933181762695312
# 7 	Coefficient: 0.9561071378289103 	RMSE: 6.290857862490507 	Time taken:  0.034173011779785156
# 8 	Coefficient: 0.9579818577070063 	RMSE: 6.290457747135269 	Time taken:  0.0019578933715820312
# 9 	Coefficient: 0.9570444977679583 	RMSE: 6.290456119788039 	Time taken:  0.0017893314361572266
# 10 	Coefficient: 0.9575131777374823 	RMSE: 6.290406510406307 	Time taken:  0.006531953811645508
# 11 	Coefficient: 0.9572788377527204 	RMSE: 6.290418709368783 	Time taken:  0.0022950172424316406
# 12 	Coefficient: 0.9573960077451014 	RMSE: 6.290409458439173 	Time taken:  0.0016851425170898438
# 13 	Coefficient: 0.9574545927412919 	RMSE: 6.290407196559651 	Time taken:  0.0017871856689453125
# 14 	Coefficient: 0.9574838852393871 	RMSE: 6.2904066565171455 	Time taken:  0.001973867416381836
# 15 	Coefficient: 0.9574985314884348 	RMSE: 6.290406534220265 	Time taken:  0.002027750015258789
# 16 	Coefficient: 0.9575058546129586 	RMSE: 6.29040651000292 	Time taken:  0.0022859573364257812
# 17 	Coefficient: 0.9575095161752205 	RMSE: 6.290406507127022 	Time taken:  0.002276897430419922
# 18 	Coefficient: 0.9575076853940896 	RMSE: 6.290406507795576 	Time taken:  0.0026988983154296875
# 19 	Coefficient: 0.957508600784655 	RMSE: 6.29040650726895 	Time taken:  0.002777099609375
# 20 	Coefficient: 0.9575090584799377 	RMSE: 6.290406507149901 	Time taken:  0.002835988998413086
# 21 	Coefficient: 0.9575092873275791 	RMSE: 6.290406507126439 	Time taken:  0.0029408931732177734
# 22 	Coefficient: 0.9575094017513999 	RMSE: 6.290406507123727 	Time taken:  0.002936840057373047
# 23 	Coefficient: 0.9575093445394895 	RMSE: 6.290406507124333 	Time taken:  0.0030546188354492188
# 24 	Coefficient: 0.9575093731454447 	RMSE: 6.290406507123841 	Time taken:  0.0037169456481933594
# 25 	Coefficient: 0.9575093874484223 	RMSE: 6.290406507123736 	Time taken:  0.0032930374145507812
# 26 	Coefficient: 0.9575093945999111 	RMSE: 6.290406507123719 	Time taken:  0.003451108932495117
# 27 	Coefficient: 0.9575093981756555 	RMSE: 6.290406507123722 	Time taken:  0.003631114959716797
# 28 	Coefficient: 0.9575093963877833 	RMSE: 6.290406507123717 	Time taken:  0.0038728713989257812
# 29 	Coefficient: 0.9575093954938472 	RMSE: 6.290406507123719 	Time taken:  0.004174947738647461
# 30 	Coefficient: 0.9575093959408152 	RMSE: 6.290406507123719 	Time taken:  0.003969669342041016
# 31 	Coefficient: 0.9575093957173312 	RMSE: 6.290406507123719 	Time taken:  0.004129886627197266
# 32 	Coefficient: 0.9575093956055891 	RMSE: 6.290406507123719 	Time taken:  0.004400014877319336
# 33 	Coefficient: 0.9575093955497181 	RMSE: 6.290406507123719 	Time taken:  0.004336833953857422
# 34 	Coefficient: 0.9575093955776537 	RMSE: 6.290406507123719 	Time taken:  0.004526853561401367
# 35 	Coefficient: 0.9575093955916214 	RMSE: 6.290406507123719 	Time taken:  0.0046498775482177734
# 36 	Coefficient: 0.9575093955986053 	RMSE: 6.290406507123716 	Time taken:  0.004820346832275391
# 37 	Coefficient: 0.9575093955951133 	RMSE: 6.290406507123719 	Time taken:  0.0050618648529052734
# 38 	Coefficient: 0.9575093955933673 	RMSE: 6.290406507123719 	Time taken:  0.005013227462768555
# 39 	Coefficient: 0.9575093955924944 	RMSE: 6.290406507123719 	Time taken:  0.005256175994873047
# 40 	Coefficient: 0.9575093955929308 	RMSE: 6.290406507123719 	Time taken:  0.005259990692138672
# 41 	Coefficient: 0.9575093955931491 	RMSE: 6.290406507123717 	Time taken:  0.005479097366333008
# 42 	Coefficient: 0.9575093955930399 	RMSE: 6.290406507123717 	Time taken:  0.005721092224121094
# 43 	Coefficient: 0.9575093955930944 	RMSE: 6.290406507123718 	Time taken:  0.005708932876586914
# 44 	Coefficient: 0.9575093955931218 	RMSE: 6.290406507123717 	Time taken:  0.006007194519042969
# 45 	Coefficient: 0.9575093955931081 	RMSE: 6.290406507123716 	Time taken:  0.006072998046875
# 46 	Coefficient: 0.9575093955931013 	RMSE: 6.290406507123717 	Time taken:  0.006020784378051758
# 47 	Coefficient: 0.9575093955930979 	RMSE: 6.290406507123718 	Time taken:  0.006142377853393555
# 48 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.007100820541381836
# 49 	Coefficient: 0.9575093955930953 	RMSE: 6.290406507123718 	Time taken:  0.006552934646606445
# 50 	Coefficient: 0.9575093955930958 	RMSE: 6.290406507123718 	Time taken:  0.009474039077758789
# 51 	Coefficient: 0.957509395593096 	RMSE: 6.290406507123719 	Time taken:  0.0068781375885009766
# 52 	Coefficient: 0.9575093955930961 	RMSE: 6.290406507123717 	Time taken:  0.007626056671142578
# 53 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.006949186325073242
# 54 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.0074920654296875
# 55 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.00845789909362793
# 56 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.010542869567871094
# 57 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.007290840148925781
# 58 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.00776219367980957
# 59 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.007762908935546875
# 60 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.007846355438232422
# 61 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.007975101470947266
# 62 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.008082866668701172
# 63 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.008760690689086914
# 64 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.008409976959228516
# 65 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.008756160736083984
# 66 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.008661031723022461
# 67 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.008744955062866211
# 68 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.008935928344726562
# 69 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.00907588005065918
# 70 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.00915217399597168
# 71 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.009217023849487305
# 72 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.009595870971679688
# 73 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.010966062545776367
# 74 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.011651039123535156
# 75 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.010456085205078125
# 76 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.010071992874145508
# 77 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.010712146759033203
# 78 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.010282039642333984
# 79 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.013688802719116211
# 80 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.010955095291137695
# 81 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.010788917541503906
# 82 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.010748863220214844
# 83 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.01143503189086914
# 84 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.011426925659179688
# 85 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.01116323471069336
# 86 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.01133584976196289
# 87 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.011381864547729492
# 88 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.011639118194580078
# 89 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.011587858200073242
# 90 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.011765003204345703
# 91 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.012940168380737305
# 92 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.013092041015625
# 93 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.013211965560913086
# 94 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.012663841247558594
# 95 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.01278996467590332
# 96 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.012827873229980469
# 97 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.012787818908691406
# 98 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.013130903244018555
# 99 	Coefficient: 0.9575093955930962 	RMSE: 6.290406507123719 	Time taken:  0.013782978057861328

# %%
calculate_rmse(df["Episode_Length_minutes"] * 0.9575093955930962, df["Listening_Time_minutes"])
# Out:
# 6.290406507123719
